# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
from wordcloud import WordCloud
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn import preprocessing

# %%
df=pd.read_csv("C:\\Users\\aadhi\\Downloads/Master Table Migrant with Code.csv")
df.head()
# Out:
#    Res. No                               Age  Gender Marital status  \
# 0        1  3Up to 30 Years old-40 Years old  female         single
# 1        2                Up to 30 Years old    male         single
# 2        3  3Up to 30 Years old-40 Years old    male         single
# 3        4    4Up to 30 Years old and Above     male      partnered
# 4        5  3Up to 30 Years old-40 Years old    male         single
#
#           Education               Income Covid- infected or not  \
# 0                no      Up to Rs.15000                negative
# 1                no  Rs. 15001-Rs. 20000               negative
# 2  school completed      Up to Rs.15000                negative
# 3                no  Rs. 15001-Rs. 20000               negative
# 4                no      Up to Rs.15000                negative
#
#                CAS1              CAS2          CAS3          CAS4  \
# 0              rare              rare  several days  several days
# ...

# %%
le = preprocessing.LabelEncoder()
df1 = df.apply(LabelEncoder().fit_transform)

# %%
df1
# Out:
#       Res. No  Age  Gender  Marital status  Education  Income  \
# 0           0    0       0               1          0       2
# 1           1    2       1               1          0       1
# 2           2    0       1               1          1       2
# 3           3    1       1               0          0       1
# 4           4    0       1               1          0       2
# 5           5    0       0               1          0       2
# 6           6    2       0               1          1       2
# 7           7    2       1               1          2       1
# 8           8    0       1               1          0       2
# 9           9    2       0               1          0       2
# 10         10    2       0               0          1       0
# 11         11    0       1               1          0       2
# 12         12    2       0               0          2       0
# 13         13    2       0               1          0       2
# ...

# %%
plt.subplots(1,5,figsize=(16,5))
plt.tight_layout(pad=1)

# %%
sns.set_style("whitegrid")

# %%
plt.figure(figsize=(20, 3))
plt.bar(df['Age'],df['CAS1'])
# Out:
# <BarContainer object of 1350 artists>

# %%
plt.figure(figsize=(20, 3))
plt.bar(df['Age'],df['CAS2'])
# Out:
# <BarContainer object of 1350 artists>

# %%
plt.figure(figsize=(20, 3))
plt.bar(df['Age'],df['CAS3'])
# Out:
# <BarContainer object of 1350 artists>

# %%
plt.figure(figsize=(20, 3))
plt.bar(df['Age'],df['CAS4'])
# Out:
# <BarContainer object of 1350 artists>

# %%
plt.figure(figsize=(20, 3))
plt.bar(df['Age'],df['CAS5'])
# Out:
# <BarContainer object of 1350 artists>

# %%
plt.figure(figsize = (10,6))
CAS1= df['CAS1'].value_counts()
CAS1
# Out:
# rare                499
# no                  467
# several days        208
# More than a week    176
# Name: CAS1, dtype: int64

# %%
plt.figure(figsize = (10,6))
value = df['CAS1'].value_counts()
plt.title('Felt dizzy, lightheaded, or faint, when read or listened to news about the coronavirus.')
plt.pie(value, autopct = '%0.02f', labels=  ['rare', 'no', 'several days','more than a week'], startangle = 90, shadow = True)
plt.show()

# %%
plt.figure(figsize = (10,6))
CAS2 = df['CAS2'].value_counts()
CAS2
# Out:
# no                  529
# rare                464
# several days        186
# More than a week    171
# Name: CAS2, dtype: int64

# %%
plt.figure(figsize = (10,6))
value = df['CAS2'].value_counts()
plt.title('Faced trouble in falling asleep thinking about the corona virus')
plt.pie(value, autopct = '%0.02f',labels=  ['rare', 'no', 'several days','more than a week'], startangle = 90, shadow = True)
plt.show()

# %%
plt.figure(figsize = (10,6))
CAS3 = df['CAS3'].value_counts()
CAS3
# Out:
# rare                493
# no                  405
# several days        279
# More than a week    173
# Name: CAS3, dtype: int64

# %%
plt.figure(figsize = (10,6))
value = df['CAS3'].value_counts()
plt.title('Felt paralyzed or frozen when thought about corona virus')
plt.pie(value, autopct = '%0.02f',labels=  ['rare', 'no', 'several days','more than a week'], startangle = 90, shadow = True)
plt.show()

# %%
plt.figure(figsize = (10,6))
CAS4 = df['CAS4'].value_counts()
CAS4
# Out:
# rare                505
# no                  408
# several days        238
# More than a week    199
# Name: CAS4, dtype: int64

# %%
plt.figure(figsize = (10,6))
value = df['CAS4'].value_counts()
plt.title('Lost interest in eating when I thought about Corona Virus')
plt.pie(value, autopct = '%0.02f',labels=  ['rare', 'no', 'several days','more than a week'], startangle = 90, shadow = True)
plt.show()

# %%
plt.figure(figsize = (10,6))
CAS5 = df['CAS5'].value_counts()
CAS5
# Out:
# no                  458
# rare                448
# several days        267
# More than a week    177
# Name: CAS5, dtype: int64

# %%
plt.figure(figsize = (10,6))
value = df['CAS5'].value_counts()
plt.title('Felt nauseous or had stomach problems when you thinking about Corona Virus or when I was exposed to information about the Corona Virus')
plt.pie(value, autopct = '%0.02f',labels=  ['rare', 'no', 'several days','more than a week'], startangle = 90, shadow = True)
plt.show()

# %%
plt.figure(figsize = (8,6))
sns.distplot(df1['CAS1'], color=  'g')

# %%
plt.figure(figsize = (8,6))
sns.distplot(df1['CAS2'], color=  'g')

# %%
plt.figure(figsize = (8,6))
sns.distplot(df1['CAS3'], color=  'g')

# %%
plt.figure(figsize = (8,6))
sns.distplot(df1['CAS4'], color=  'g')

# %%
plt.figure(figsize = (8,6))
sns.distplot(df1['CAS5'], color=  'g')

# %%
plt.plot(CAS1)
plt.plot(CAS2)
plt.plot(CAS3)
plt.plot(CAS4)
plt.plot(CAS5)
plt.legend(['CAS1','CAS2','CAS3','CAS4','CAS5'])

# %%
age = df['Age'].value_counts()
age
# Out:
# Up to 30 Years old                  728
# 3Up to 30 Years old-40 Years old    345
# 4Up to 30 Years old and Above       277
# Name: Age, dtype: int64

# %%
gender = df['Gender'].value_counts()
gender
# Out:
# male      759
# female    591
# Name: Gender, dtype: int64

# %%
marital= df['Marital status'].value_counts()
marital
# Out:
# partnered    823
# single       527
# Name: Marital status, dtype: int64

# %%
Education = df['Education'].value_counts()
Education
# Out:
# no                  786
# school dropout      446
# school completed    118
# Name: Education, dtype: int64

# %%
Income = df['Income'].value_counts()
Income
# Out:
# Rs. 15001-Rs. 20000    894
# Up to Rs.15000         415
# More than Rs. 20000     41
# Name: Income, dtype: int64

# %%
Education = df['Education'].value_counts()
Education
# Out:
# no                  786
# school dropout      446
# school completed    118
# Name: Education, dtype: int64

# %%
g = sns.catplot(
    data=df1, kind="bar",
    x="Covid- infected or not", y="Gender", hue="CAS1",
    ci="sd", palette="dark", alpha=.6, height=6
)
g.despine(left=True)
g.set_axis_labels("Covid- infected or not", "gender")

# %%
g = sns.catplot(
    data=df1, kind="bar",
    x="Covid- infected or not", y="CAS1", hue="Gender",
    ci="sd", palette="dark", alpha=.6, height=6
)
g.despine(left=True)
g.set_axis_labels("Covid- infected or not", "CAS1")

# %%
g = sns.catplot(
    data=df1, kind="bar",
    x="Covid- infected or not", y="CAS1", hue="Gender",
    ci="sd", palette="dark", alpha=.6, height=6
)
g.despine(left=True)
g.set_axis_labels("Covid- infected or not", "CAS1")

# %%
g = sns.catplot(
    data=df1, kind="bar",
    x="Covid- infected or not", y="CAS1", hue="Gender",
    ci="sd", palette="dark", alpha=.6, height=6
)
g.despine(left=True)
g.set_axis_labels("Covid- infected or not", "CAS1")

# %%
g = sns.catplot(
    data=df1, kind="bar",
    x="Covid- infected or not", y="CAS1", hue="Gender",
    ci="sd", palette="dark", alpha=.6, height=6
)
g.despine(left=True)
g.set_axis_labels("Covid- infected or not", "CAS1")
